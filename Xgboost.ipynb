# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR,SVC
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from xgboost import XGBRegressor, XGBClassifier
from catboost import CatBoostRegressor
from sklearn.linear_model import HuberRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_percentage_error 
from sklearn.preprocessing import OneHotEncoder
from pycaret.regression import *

# %%
df = pd.read_csv('train.csv')

# %%
df = df.drop(['filename','ID','date'],axis=1)

# %%
label_encoder = LabelEncoder()
encoded_colors = label_encoder.fit_transform(df['sex'])
df['sex'] = encoded_colors

# %%
encoder = OneHotEncoder(sparse=False)
encoded_data = encoder.fit_transform(df[['operator']])
df = pd.concat([df, pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['operator']))], axis=1)
df = df.drop('operator',axis=1)

# %%
df = df.dropna()

# %%
x_train = df.drop('time_min', axis=1)
y_train = df['time_min']

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=41)

# %%
train = pd.concat([x_train, y_train], axis=1)
val = pd.concat([x_val, y_val], axis=1)

# %%
ms = MinMaxScaler()
x_train_ms = ms.fit_transform(x_train)
x_val_ms = ms.transform(x_val)

# %%
model_xgb = XGBRegressor(n_estimators=500, max_depth=3)
model_xgb.fit(x_train_ms, y_train)

model_rf = RandomForestRegressor(n_estimators=500, max_depth=3)
model_rf.fit(x_train_ms, y_train)

model_hb = HuberRegressor()
model_hb.fit(x_train_ms, y_train)

model_cb = CatBoostRegressor(iterations=50, depth=4)
model_cb.fit(x_train_ms, y_train)
# Out:
# Learning rate set to 0.394541
# 0:	learn: 7.2412991	total: 1.26ms	remaining: 61.7ms
# 1:	learn: 6.8588726	total: 3.4ms	remaining: 81.7ms
# 2:	learn: 6.5458504	total: 5.35ms	remaining: 83.8ms
# 3:	learn: 6.4542294	total: 6.05ms	remaining: 69.5ms
# 4:	learn: 6.3124100	total: 7.57ms	remaining: 68.1ms
# 5:	learn: 6.2085870	total: 9.28ms	remaining: 68ms
# 6:	learn: 6.1362322	total: 10.9ms	remaining: 66.9ms
# 7:	learn: 6.0716105	total: 12.4ms	remaining: 65.2ms
# 8:	learn: 5.9507910	total: 13.9ms	remaining: 63.4ms
# 9:	learn: 5.8410148	total: 16ms	remaining: 63.9ms
# 10:	learn: 5.7771414	total: 17.8ms	remaining: 63.2ms
# 11:	learn: 5.7323500	total: 19.5ms	remaining: 61.8ms
# 12:	learn: 5.6779202	total: 21.3ms	remaining: 60.8ms
# 13:	learn: 5.6021385	total: 23.3ms	remaining: 59.9ms
# 14:	learn: 5.5611823	total: 25.2ms	remaining: 58.9ms
# 15:	learn: 5.5208200	total: 26.6ms	remaining: 56.4ms
# 16:	learn: 5.4542068	total: 28.5ms	remaining: 55.4ms
# 17:	learn: 5.3838415	total: 30.4ms	remaining: 54ms
# 18:	learn: 5.3538295	total: 32.3ms	remaining: 52.7ms
# 19:	learn: 5.2490307	total: 34.3ms	remaining: 51.4ms
# 20:	learn: 5.1532212	total: 36.3ms	remaining: 50.1ms
# 21:	learn: 5.1291446	total: 38.1ms	remaining: 48.5ms
# 22:	learn: 5.0215670	total: 39.2ms	remaining: 46ms
# 23:	learn: 4.9862047	total: 40.8ms	remaining: 44.2ms
# 24:	learn: 4.9109533	total: 42.8ms	remaining: 42.8ms
# 25:	learn: 4.8841207	total: 44.7ms	remaining: 41.3ms
# 26:	learn: 4.8155816	total: 46.1ms	remaining: 39.3ms
# 27:	learn: 4.8031013	total: 48ms	remaining: 37.7ms
# 28:	learn: 4.7217966	total: 49.8ms	remaining: 36.1ms
# 29:	learn: 4.6844086	total: 51.7ms	remaining: 34.4ms
# 30:	learn: 4.6288118	total: 52.8ms	remaining: 32.4ms
# 31:	learn: 4.5546357	total: 54.3ms	remaining: 30.5ms
# 32:	learn: 4.5012220	total: 56.1ms	remaining: 28.9ms
# 33:	learn: 4.4439618	total: 58.1ms	remaining: 27.4ms
# 34:	learn: 4.4211745	total: 59.6ms	remaining: 25.5ms
# 35:	learn: 4.4062714	total: 61.6ms	remaining: 23.9ms
# 36:	learn: 4.3838164	total: 63.3ms	remaining: 22.2ms
# 37:	learn: 4.3640996	total: 64.8ms	remaining: 20.5ms
# 38:	learn: 4.3574163	total: 66ms	remaining: 18.6ms
# 39:	learn: 4.3130892	total: 67.7ms	remaining: 16.9ms
# 40:	learn: 4.2604467	total: 69.8ms	remaining: 15.3ms
# 41:	learn: 4.1845235	total: 71.2ms	remaining: 13.6ms
# 42:	learn: 4.1582538	total: 73.1ms	remaining: 11.9ms
# 43:	learn: 4.1324698	total: 74.9ms	remaining: 10.2ms
# 44:	learn: 4.0857773	total: 76.7ms	remaining: 8.52ms
# 45:	learn: 4.0525310	total: 78ms	remaining: 6.78ms
# 46:	learn: 3.9931437	total: 79.8ms	remaining: 5.09ms
# 47:	learn: 3.9738776	total: 81.4ms	remaining: 3.39ms
# 48:	learn: 3.9671088	total: 83.1ms	remaining: 1.7ms
# 49:	learn: 3.9437474	total: 84.8ms	remaining: 0us

# %%
xgb_pred_train = model_xgb.predict(x_train_ms)
print(mean_absolute_percentage_error(y_train, xgb_pred_train))

rf_pred_train = model_rf.predict(x_train_ms)
print(mean_absolute_percentage_error(y_train, rf_pred_train))

hb_pred_train = model_hb.predict(x_train_ms)
print(mean_absolute_percentage_error(y_train, hb_pred_train))

cb_pred_train = model_cb.predict(x_train_ms)
print(mean_absolute_percentage_error(y_train, cb_pred_train))
# Out:
# 0.03619540782623542
# 0.4800199667759742
# 0.4673340939786657
# 0.3144942141977625

# %%
xgb_pred = model_xgb.predict(x_val_ms)
print(mean_absolute_percentage_error(y_val, xgb_pred))

rf_pred = model_rf.predict(x_val_ms)
print(mean_absolute_percentage_error(y_val,rf_pred))

hb_pred = model_hb.predict(x_val_ms)
print(mean_absolute_percentage_error(y_val,hb_pred))

cb_pred = model_cb.predict(x_val_ms)
print(mean_absolute_percentage_error(y_val,cb_pred))
# Out:
# 0.4099325223462076
# 0.3849580568407149
# 0.370201103310999
# 0.37074937243524125

# %%
ensemble_pred = (xgb_pred + rf_pred + hb_pred + cb_pred)/4
print(mean_absolute_percentage_error(y_val, ensemble_pred))
# Out:
# 0.3675898161103057

# %%
s = setup(df, target = 'time_min', session_id = 123, train_size = 0.8)
best = compare_models( n_select=5)
# Out:
# <style type="text/css">
# #T_7d6d8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7d6d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d6d8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7d6d8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d6d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d6d8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7d6d8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d6d8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7d6d8_row1_col1" class="data row1 col1" >time_min</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d6d8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7d6d8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d6d8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7d6d8_row3_col1" class="data row3 col1" >(427, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d6d8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7d6d8_row4_col1" class="data row4 col1" >(427, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d6d8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7d6d8_row5_col1" class="data row5 col1" >(341, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d6d8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7d6d8_row6_col1" class="data row6 col1" >(86, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d6d8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7d6d8_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d6d8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_7d6d8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d6d8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_7d6d8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7d6d8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_7d6d8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7d6d8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_7d6d8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7d6d8_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_7d6d8_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7d6d8_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_7d6d8_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7d6d8_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_7d6d8_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7d6d8_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_7d6d8_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7d6d8_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_7d6d8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7d6d8_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_7d6d8_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7d6d8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7d6d8_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_7d6d8_row18_col1" class="data row18 col1" >4b2a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1f03d th {
#   text-align: left;
# }
# #T_1f03d_row0_col0, #T_1f03d_row0_col1, #T_1f03d_row0_col2, #T_1f03d_row0_col3, #T_1f03d_row0_col5, #T_1f03d_row0_col6, #T_1f03d_row1_col0, #T_1f03d_row1_col1, #T_1f03d_row1_col2, #T_1f03d_row1_col3, #T_1f03d_row1_col4, #T_1f03d_row1_col5, #T_1f03d_row1_col6, #T_1f03d_row2_col0, #T_1f03d_row2_col1, #T_1f03d_row2_col4, #T_1f03d_row2_col5, #T_1f03d_row2_col6, #T_1f03d_row3_col0, #T_1f03d_row3_col1, #T_1f03d_row3_col2, #T_1f03d_row3_col3, #T_1f03d_row3_col4, #T_1f03d_row3_col5, #T_1f03d_row3_col6, #T_1f03d_row4_col0, #T_1f03d_row4_col1, #T_1f03d_row4_col2, #T_1f03d_row4_col3, #T_1f03d_row4_col4, #T_1f03d_row4_col5, #T_1f03d_row4_col6, #T_1f03d_row5_col0, #T_1f03d_row5_col1, #T_1f03d_row5_col2, #T_1f03d_row5_col3, #T_1f03d_row5_col4, #T_1f03d_row5_col6, #T_1f03d_row6_col0, #T_1f03d_row6_col2, #T_1f03d_row6_col3, #T_1f03d_row6_col4, #T_1f03d_row6_col5, #T_1f03d_row7_col0, #T_1f03d_row7_col1, #T_1f03d_row7_col2, #T_1f03d_row7_col3, #T_1f03d_row7_col4, #T_1f03d_row7_col5, #T_1f03d_row7_col6, #T_1f03d_row8_col0, #T_1f03d_row8_col1, #T_1f03d_row8_col2, #T_1f03d_row8_col3, #T_1f03d_row8_col4, #T_1f03d_row8_col5, #T_1f03d_row8_col6, #T_1f03d_row9_col0, #T_1f03d_row9_col1, #T_1f03d_row9_col2, #T_1f03d_row9_col3, #T_1f03d_row9_col4, #T_1f03d_row9_col5, #T_1f03d_row9_col6, #T_1f03d_row10_col0, #T_1f03d_row10_col1, #T_1f03d_row10_col2, #T_1f03d_row10_col3, #T_1f03d_row10_col4, #T_1f03d_row10_col5, #T_1f03d_row10_col6, #T_1f03d_row11_col0, #T_1f03d_row11_col1, #T_1f03d_row11_col2, #T_1f03d_row11_col3, #T_1f03d_row11_col4, #T_1f03d_row11_col5, #T_1f03d_row11_col6, #T_1f03d_row12_col0, #T_1f03d_row12_col1, #T_1f03d_row12_col2, #T_1f03d_row12_col3, #T_1f03d_row12_col4, #T_1f03d_row12_col5, #T_1f03d_row12_col6, #T_1f03d_row13_col0, #T_1f03d_row13_col1, #T_1f03d_row13_col2, #T_1f03d_row13_col3, #T_1f03d_row13_col4, #T_1f03d_row13_col5, #T_1f03d_row13_col6, #T_1f03d_row14_col0, #T_1f03d_row14_col1, #T_1f03d_row14_col2, #T_1f03d_row14_col3, #T_1f03d_row14_col4, #T_1f03d_row14_col5, #T_1f03d_row14_col6, #T_1f03d_row15_col0, #T_1f03d_row15_col1, #T_1f03d_row15_col2, #T_1f03d_row15_col3, #T_1f03d_row15_col4, #T_1f03d_row15_col5, #T_1f03d_row15_col6, #T_1f03d_row16_col0, #T_1f03d_row16_col1, #T_1f03d_row16_col2, #T_1f03d_row16_col3, #T_1f03d_row16_col4, #T_1f03d_row16_col5, #T_1f03d_row16_col6, #T_1f03d_row17_col0, #T_1f03d_row17_col1, #T_1f03d_row17_col2, #T_1f03d_row17_col3, #T_1f03d_row17_col4, #T_1f03d_row17_col5, #T_1f03d_row17_col6, #T_1f03d_row18_col0, #T_1f03d_row18_col1, #T_1f03d_row18_col2, #T_1f03d_row18_col3, #T_1f03d_row18_col4, #T_1f03d_row18_col5, #T_1f03d_row18_col6, #T_1f03d_row19_col0, #T_1f03d_row19_col1, #T_1f03d_row19_col2, #T_1f03d_row19_col3, #T_1f03d_row19_col4, #T_1f03d_row19_col5, #T_1f03d_row19_col6 {
#   text-align: left;
# }
# #T_1f03d_row0_col4, #T_1f03d_row2_col2, #T_1f03d_row2_col3, #T_1f03d_row5_col5, #T_1f03d_row6_col1, #T_1f03d_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1f03d_row0_col7, #T_1f03d_row1_col7, #T_1f03d_row2_col7, #T_1f03d_row3_col7, #T_1f03d_row4_col7, #T_1f03d_row5_col7, #T_1f03d_row6_col7, #T_1f03d_row7_col7, #T_1f03d_row8_col7, #T_1f03d_row9_col7, #T_1f03d_row10_col7, #T_1f03d_row11_col7, #T_1f03d_row12_col7, #T_1f03d_row13_col7, #T_1f03d_row14_col7, #T_1f03d_row15_col7, #T_1f03d_row17_col7, #T_1f03d_row18_col7, #T_1f03d_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1f03d_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1f03d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f03d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1f03d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1f03d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1f03d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1f03d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1f03d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1f03d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1f03d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f03d_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_1f03d_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_1f03d_row0_col1" class="data row0 col1" >5.0451</td>
#       <td id="T_1f03d_row0_col2" class="data row0 col2" >48.4319</td>
#       <td id="T_1f03d_row0_col3" class="data row0 col3" >6.8412</td>
#       <td id="T_1f03d_row0_col4" class="data row0 col4" >0.3186</td>
#       <td id="T_1f03d_row0_col5" class="data row0 col5" >0.4784</td>
#       <td id="T_1f03d_row0_col6" class="data row0 col6" >0.5647</td>
#       <td id="T_1f03d_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_1f03d_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_1f03d_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_1f03d_row1_col1" class="data row1 col1" >5.0422</td>
#       <td id="T_1f03d_row1_col2" class="data row1 col2" >48.4371</td>
#       <td id="T_1f03d_row1_col3" class="data row1 col3" >6.8434</td>
#       <td id="T_1f03d_row1_col4" class="data row1 col4" >0.3161</td>
#       <td id="T_1f03d_row1_col5" class="data row1 col5" >0.4774</td>
#       <td id="T_1f03d_row1_col6" class="data row1 col6" >0.5594</td>
#       <td id="T_1f03d_row1_col7" class="data row1 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_1f03d_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_1f03d_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_1f03d_row2_col1" class="data row2 col1" >5.0098</td>
#       <td id="T_1f03d_row2_col2" class="data row2 col2" >47.5715</td>
#       <td id="T_1f03d_row2_col3" class="data row2 col3" >6.8059</td>
#       <td id="T_1f03d_row2_col4" class="data row2 col4" >0.3159</td>
#       <td id="T_1f03d_row2_col5" class="data row2 col5" >0.4717</td>
#       <td id="T_1f03d_row2_col6" class="data row2 col6" >0.5269</td>
#       <td id="T_1f03d_row2_col7" class="data row2 col7" >1.1600</td>
#     </tr>
#     <tr>
#       <th id="T_1f03d_level0_row3" class="row_heading level0 row3" >lar</th>
#       <td id="T_1f03d_row3_col0" class="data row3 col0" >Least Angle Regression</td>
#       <td id="T_1f03d_row3_col1" class="data row3 col1" >5.0427</td>
#       <td id="T_1f03d_row3_col2" class="data row3 col2" >48.4788</td>
#       <td id="T_1f03d_row3_col3" class="data row3 col3" >6.8470</td>
#       <td id="T_1f03d_row3_col4" class="data row3 col4" >0.3149</td>
#       <td id="T_1f03d_row3_col5" class="data row3 col5" >0.4773</td>
#       <td id="T_1f03d_row3_col6" class="data row3 col6" >0.5581</td>
#       <td id="T_1f03d_row3_col7" class="data row3 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_1f03d_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_1f03d_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_1f03d_row4_col1" class="data row4 col1" >5.0427</td>
#       <td id="T_1f03d_row4_col2" class="data row4 col2" >48.4791</td>
#       <td id="T_1f03d_row4_col3" class="data row4 col3" >6.8470</td>
#       <td id="T_1f03d_row4_col4" class="data row4 col4" >0.3149</td>
#       <td id="T_1f03d_row4_col5" class="data row4 col5" >0.4773</td>
#       <td id="T_1f03d_row4_col6" class="data row4 col6" >0.5581</td>
#       <td id="T_1f03d_row4_col7" class="data row4 col7" >1.0980</td>
#     </tr>
#     <tr>
#       <th id="T_1f03d_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_1f03d_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_1f03d_row5_col1" class="data row5 col1" >5.0350</td>
#       <td id="T_1f03d_row5_col2" class="data row5 col2" >47.9664</td>
#       <td id="T_1f03d_row5_col3" class="data row5 col3" >6.8404</td>
#       <td id="
# Processing:   0%|          | 0/89 [00:00<?, ?it/s]

# %%
feature_importance = model_xgb.feature_importances_

# 각 특성의 중요도 출력
for i, importance in enumerate(feature_importance):
    print(f'Feature {i+1}: {importance}')
# Out:
# Feature 1: 0.01455379743129015
# Feature 2: 0.0338318832218647
# Feature 3: 0.06608369201421738
# Feature 4: 0.016791395843029022
# Feature 5: 0.01786457933485508
# Feature 6: 0.0366649255156517
# Feature 7: 0.010511876083910465
# Feature 8: 0.0
# Feature 9: 0.0
# Feature 10: 0.0
# Feature 11: 0.8036978244781494

# %%
print(df[df['operator_Y']==1]['time_min'].describe())
print(df[df['operator_A']==1]['time_min'].describe())
print(df[df['operator_K']==1]['time_min'].describe())
print(df[df['operator_P']==1]['time_min'].describe())
# Out:
# count    93.000000
# mean     21.580645
# std       8.876352
# min       5.000000
# 25%      15.000000
# 50%      20.000000
# 75%      25.000000
# max      50.000000
# Name: time_min, dtype: float64
# count    194.000000
# mean       9.097938
# std        5.246829
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       11.000000
# max       30.000000
# Name: time_min, dtype: float64
# count    92.000000
# mean     13.434783
# std       6.347630
# min       4.000000
# 25%       9.750000
# 50%      12.000000
# 75%      16.000000
# max      50.000000
# Name: time_min, dtype: float64
# count    48.000000
# mean     14.854167
# std       7.322334
# min       3.000000
# 25%      10.750000
# 50%      14.000000
# 75%      18.000000
# max      40.000000
# Name: time_min, dtype: float64
